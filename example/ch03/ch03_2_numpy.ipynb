# %% [markdown]
# # ３章 データ構造

# %% [markdown]
# ## 3.2 numPy

# %% [markdown]
# ### 3.2.1　NumPyの関数

# %%
python_2d_list =[[1, 3, 5], [2, 4, 6], [7, 9, 11]]

# %%
first_column = [python_2d_list[i][0] for i in range(len(python_2d_list))]

# %%
first_column
# Out:
# [1, 2, 7]

# %%
import numpy as np

np_2d_array = np.array([[1, 3, 5], [2, 4, 6], [7, 9, 11]])

first_column = np_2d_array[:, 0]

# %%
first_column
# Out:
# array([1, 2, 7])

# %% [markdown]
# ### 3.2.2　NumPyのパフォーマンスに関する考察

# %%
mixed_type_list = ["one", 2, 3.14]

# %%
mixed_type_array = np.array(["one", 2, 3.14])

# %%
print(mixed_type_array)
# Out:
# ['one' '2' '3.14']

# %%
integer_array = np.array([1, 2, 3])
print(integer_array.dtype)
# Out:
# int64

# %% [markdown]
# ##### ●Pythonのリストと比較して、NumPyを使うことでパフォーマンスが向上する例

# %%
random_int_array = np.random.randint(1, 100_000, 100_000)
random_int_list = list(random_int_array)

# %%
# %%timeit -r 7 -n 100
sum(random_int_list)
# Out:
# 1.76 ms ± 59.1 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit -r 7 -n 100
np.sum(random_int_array)
# Out:
# 12.1 μs ± 2.41 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %% [markdown]
# ##### ●配列を適切なスペースで初期化する

# %%
array_to_fill = np.zeros(1000)

# %%
random_int_array = np.random.randint(1, 100_000, 100_000)

# %%
random_int_array.nbytes
# Out:
# 800000

# %%
random_int_array.dtype
# Out:
# dtype('int64')

# %%
random_int_array_32 = random_int_array.astype(np.int32)

# %%
random_int_array_32.nbytes
# Out:
# 400000

# %%
small_array = np.array([1, 3, 5], dtype=np.int16)

# %%
small_array.dtype
# Out:
# dtype('int16')

# %% [markdown]
# ### 3.2.3　Daskを使った配列演算

# %% [markdown]
# ##### ●環境によってはすごく時間がかかるかもしれないので、注意。30億 -> 10億でよいかも

# %%
import numpy as np
large_np_array = np.random.randint(1, 100000, 30_0000_0000)

# %%
# %%timeit -r 1 -n 7
np.max(large_np_array)
# Out:
# 6.35 s ± 0 ns per loop (mean ± std. dev. of 1 run, 7 loops each)

# %%
import dask.array as da

large_np_array = np.random.randint(1, 100000, 30_0000_0000)

# %%
large_dask_array = da.from_array(large_np_array)

# %%
# %%timeit -r 1 -n 7
array_max = large_dask_array.max()
array_max.compute()
# Out:
# 4.39 s ± 0 ns per loop (mean ± std. dev. of 1 run, 7 loops each)

# %%
array_max = large_dask_array.max()

# %%
# %%time
array_max.compute()
# Out:
# CPU times: user 1.31 s, sys: 13.4 s, total: 14.7 s
# Wall time: 4.4 s
# np.int64(99999)

# %%
from dask.distributed import Client

client = Client(n_workers=4)

# %%
client
# Out:
# <Client: 'tcp://127.0.0.1:58784' processes=4 threads=12, memory=32.00 GiB>

# %% [markdown]
# ### 3.3 機械学習における配列

# %%
import numpy as np

np_tensor = np.random.rand(4,4)

# %%
np_tensor
# Out:
# array([[0.05751854, 0.90090351, 0.42867323, 0.28850905],
#        [0.64892238, 0.05873513, 0.87582391, 0.89069449],
#        [0.76038317, 0.96535135, 0.03324167, 0.247393  ],
#        [0.06658472, 0.32494639, 0.03871946, 0.82843642]])

# %% [markdown]
# ##### メモ： 「`pip install tensorflow`」でインストール

# %%
import tensorflow as tf

tf_tensor = tf.convert_to_tensor(np_tensor)

# %%
tf_tensor
# Out:
# <tf.Tensor: shape=(4, 4), dtype=float64, numpy=
# array([[0.05751854, 0.90090351, 0.42867323, 0.28850905],
#        [0.64892238, 0.05873513, 0.87582391, 0.89069449],
#        [0.76038317, 0.96535135, 0.03324167, 0.247393  ],
#        [0.06658472, 0.32494639, 0.03871946, 0.82843642]])>

# %% [markdown]
# ##### メモ： 「`pip install torch`」でインストール

# %%
import torch

pytorch_tensor = torch.from_numpy(np_tensor)

# %%
pytorch_tensor
# Out:
# tensor([[0.0575, 0.9009, 0.4287, 0.2885],
#         [0.6489, 0.0587, 0.8758, 0.8907],
#         [0.7604, 0.9654, 0.0332, 0.2474],
#         [0.0666, 0.3249, 0.0387, 0.8284]], dtype=torch.float64)
