# %% [markdown]
# # 6章 コードのフォーマット、リンティング、型チェック
#
# ## 6.3 型チェック

# %%
import math

my_float = '100'
print(math.sqrt(my_float))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 import math
#       3 my_float = '100'
# ----> 4 print(math.sqrt(my_float))
#
# TypeError: must be real number, not str

# %%
my_variable = 10
print(type(my_variable))
# Out:
# <class 'int'>

# %%
my_variable = 'hello'
print(type(my_variable))
# Out:
# <class 'str'>
